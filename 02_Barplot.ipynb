# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
phool=sns.load_dataset("iris")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="species", y= "sepal_width", data=phool)
plt.title("Phholon ka plot")
plt.show()

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="sex", y= "alone",hue="who", data=kashti)
plt.show()

# %% [markdown]
# ##  Setting order on axis

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="sex", y= "alone",hue="who", data=kashti, order=("female","male"))
plt.show()

# %% [markdown]
# ## Coloring (Color Palltes)

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="sex", y= "alone",hue="who", data=kashti, order=("female","male"), color="green")
plt.show()

# %% [markdown]
# ## Removing error bars sing confidence interval

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="sex", y= "alone",hue="who", data=kashti, order=("female","male"), color="green", ci=None)
plt.show()

# %% [markdown]
# ## Using built in palltets

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
#phool
plt.figure(figsize=(10,8))
#draw a line plot
#it will be between 2 numeric variables
sns.barplot(x="sex", y= "alone",hue="who", data=kashti, order=("female","male"), color="green", ci=None, palette='pastel')
plt.show()

# %% [markdown]
# ## Using estimator

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
sns.barplot(x="class", y= "fare",hue="sex", data=kashti, estimator=mean)
plt.show()

# %% [markdown]
# ## Saturation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
sns.barplot(x="class", y= "fare",hue="sex", data=kashti, estimator=mean, saturation=0.6)
plt.show()

# %% [markdown]
# ### Horizontal plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
sns.set_style(style=None, rc=None)
#load dataset
kashti=sns.load_dataset("titanic")
sns.barplot(x="fare", y= "class",hue="sex", data=kashti, saturation=0.6)
plt.show()
